# %% [markdown]
# Import the libraries and upload the IRIS.csv file into the notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-76251ba9-23f0-4caf-b7bb-2d24ffac0842" name="files[]" multiple disabled />
#      <output id="result-76251ba9-23f0-4caf-b7bb-2d24ffac0842">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %% [markdown]
# Assign the uploaded file to a data frame and having a look of that.

# %%
iris_df = pd.read_csv('Iris.csv')
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# As a practice, get a good view and an clear idea of the data set, plotting the variables

# %%
sns.set()
sns.pairplot(iris_df, hue="Species", diag_kind="kde")

# %% [markdown]
# Let's split the data set into the training and testig data set. In this case, let's take 70% from the whole data set for training.

# %%
x=iris_df.iloc[:,:-1]
y=iris_df.iloc[:,4]
X_train, X_test, y_train, y_test=train_test_split(x, y, test_size=0.30)

# %%
len(X_train)
# Out:
# 105

# %%
len(X_test)
# Out:
# 45

# %% [markdown]
# Let's train and fit the model

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# Now, we can check the score of the trained model or the accurecy of the trained model.

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
y_predicted = model.predict(X_test)

# %% [markdown]
# Let's plot a heat map and get a clear idea of the outcome.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')
